# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 101)
y1 = x * np.log2(x)
y2 = x**2

plt.plot(x, y1, label='O(nlogn)')
plt.plot(x, y2, label='O(n^2)')
plt.xlabel('n')
plt.ylabel('Time')
plt.legend()
plt.show()
